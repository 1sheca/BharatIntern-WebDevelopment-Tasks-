# %%
netflix_homepage/
│
├── static/
│   └── style.css
│
├── templates/
│   └── index.html
│
└── app.py

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True)

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Netflix</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <header>
        <nav>
            <img src="{{ url_for('static', filename='netflix-logo.png') }}" alt="Netflix Logo">
        </nav>
    </header>
    <main>
        <div class="banner">
            <img src="{{ url_for('static', filename='banner.jpg') }}" alt="Banner">
        </div>
        <div class="row">
            <div class="poster">
                <img src="{{ url_for('static', filename='poster1.jpg') }}" alt="Movie 1">
            </div>
            <div class="poster">
                <img src="{{ url_for('static', filename='poster2.jpg') }}" alt="Movie 2">
            </div>
            <div class="poster">
                <img src="{{ url_for('static', filename='poster3.jpg') }}" alt="Movie 3">
            </div>
            <!-- Add more posters -->
        </div>
    </main>
    <footer>
        <p>&copy; 2023 Netflix</p>
    </footer>
</body>
</html>

# %%
body {
    font-family: Arial, sans-serif;
    margin: 0;
    padding: 0;
    background-color: #000;
    color: #fff;
}

header {
    background-color: #111;
    padding: 10px 0;
    position: fixed;
    top: 0;
    width: 100%;
    z-index: 1;
}

nav {
    max-width: 1000px;
    margin: 0 auto;
    display: flex;
    align-items: center;
}

nav img {
    width: 100px;
}

main {
    padding-top: 70px;
}

.banner img {
    width: 100%;
}

.row {
    max-width: 1000px;
    margin: 0 auto;
    display: flex;
    flex-wrap: wrap;
    justify-content: space-between;
    padding: 20px;
}

.poster {
    flex: 0 0 calc(33.33% - 20px);
    margin-bottom: 20px;
    position: relative;
}

.poster img {
    width: 100%;
    border-radius: 5px;
    box-shadow: 0px 2px 5px rgba(0, 0, 0, 0.3);
}

# %%
python app.py
